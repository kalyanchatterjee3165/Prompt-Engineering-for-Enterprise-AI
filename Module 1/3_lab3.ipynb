# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# %pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (6.9.2)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from pypdf) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (4.44.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: packaging in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (22.0)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (1.3.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (4.12.1)
# Requirement already satisfied: ffmpy in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (2.6.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.23.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (3.11.5)
# Requirement already satisfied: pydub in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.15.9)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (2.12.5)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.39.0)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (3.7.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi<1.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.128.8)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (0.36.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: fsspec in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio-client==1.3.0->gradio) (2025.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from fastapi<1.0->gradio) (0.4.2)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from fastapi<1.0->gradio) (0.49.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from fastapi<1.0->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from httpx>=0.24.1->gradio) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: requests in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.5)
# Requirement already satisfied: filelock in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.19.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.67.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.11.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from pydantic>=2.0->gradio) (2.41.5)
# Requirement already satisfied: rich>=12.3.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: colorama in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\monika201103\anaconda3\envs\new\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\monika201103\\projects\\AI-agents\\1_foundations'

# %%
reader = PdfReader("me/Monika Linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# monika4dec@gmail.com
# www.linkedin.com/in/monika-arora-
# phd-98b05313 (LinkedIn)
# Top Skills
# Analytical Skills
# Project Management
# Generative AI
# Certifications
# Certificate of Reviewing
# Data Science
# Machine Learning and Applications
# Course Certificate: Understanding
# Agentic AI
# Introduction to Image Generation
# Monika Arora, PhD
# Senior Manager | AIML, Gen AI, AI Agent - Technology SME | Ph.D
# in Artificial Intelligence
# India
# Summary
# At EXL, our team excels in leveraging Generative AI and Prompt
# Engineering to drive innovative analytics solutions that transform
# business operations. With expertise honed through multiple years
# as an Assistant Professor specializing in Artificial Intelligence,
# I've seamlessly transitioned into the industry, applying my deep
# knowledge to practical, impactful projects.
# My role as Senior Manager centers on orchestrating project
# lifecycles, ensuring excellence in execution and alignment with
# strategic business objectives. We cultivate digital capabilities
# within the organization, with a focus on empowering teams through
# comprehensive AI and analytics training. This commitment to
# knowledge-sharing and skill development is integral to sustaining
# EXL's competitive edge in a rapidly evolving technological
# landscape.
# Experience
# EXL
# 3 years 3 months
# Senior Manager
# January 2025 - Present (1 year 2 months)
# Manager
# December 2022 - December 2024 (2 years 1 month)
# Amity University
# Board Member - Industry Advisory Board
# September 2025 - Present (6 months)
# Academic–industry collaboration to review and refine program structure
# and syllabus, actively engaging experts to validate curriculum relevance,
# strengthen research alignment, and ensure strong fit with current industry skills
# and practices.
#   Page 1 of 2
# Amity University Noida
# 13 years 5 months
# Assistant Professor
# August 2009 - December 2022 (13 years 5 months)
# Noida
# Assistant Professor-Department of Artificial intelligence
# August 2009 - November 2022 (13 years 4 months)
# Education
# Thapar Institute of Engineering & Technology
# M E.  · (April 2007 - April 2009)
# Amity University
# Doctor of Philosophy - PhD, Artificial Intelligence · (July 2014 - December
# 2021)
# DIT UNIVERSITY
# Bachelor of Technology - BTech, Electrical and Electronics
# Engineering · (2003 - 2007)
# Thapar Institute of Engineering & Technology
# Master of Engineering - MEng, Artificial Intelligence
# Thapar Institute of Engineering & Technology
#   Page 2 of 2

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Monika Arora"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Monika Arora. You are answering questions on Monika Arora's website, particularly questions related to Monika Arora's career, background, skills and experience. Your responsibility is to represent Monika Arora for interactions on the website as faithfully as possible. You are given a summary of Monika Arora's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ed Donner. I'm an entrepreneur, software engineer and data scientist. I'm originally from London, England, but I moved to NYC in 2000.\nI love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nmonika4dec@gmail.com\nwww.linkedin.com/in/monika-arora-\nphd-98b05313 (LinkedIn)\nTop Skills\nAnalytical Skills\nProject Management\nGenerative AI\nCertifications\nCertificate of Reviewing\nData Science\nMachine Learning and Applications\nCourse Certificate: Understanding\nAgentic AI\nIntroduction to Image Generation\nMonika Arora, PhD\nSenior Manager | AIML, Gen AI, AI Agent - Technology SME | Ph.D\nin Artificial Intelligence\nIndia\nSummary\nAt EXL, our team excels in leveraging Generative AI and Prompt\nEngineering to drive innovative analytics solutions that transform\nbusiness operations. With expertise honed through multiple years\nas an Assistant Professor specializing in Artificial Intelligence,\nI've seamlessly transitioned into the industry, applying my deep\nknowledge to practical, impactful projects.\nMy role as Senior Manager centers on orchestrating project\nlifecycles, ensuring excellence in execution and alignment with\nstrategic business objectives. We cultivate digital capabilities\nwithin the organization, with a focus on empowering teams through\ncomprehensive AI and analytics training. This commitment to\nknowledge-sharing and skill development is integral to sustaining\nEXL's competitive edge in a rapidly evolving technological\nlandscape.\nExperience\nEXL\n3 years 3 months\nSenior Manager\nJanuary 2025\xa0-\xa0Present\xa0(1 year 2 months)\nManager\nDecember 2022\xa0-\xa0December 2024\xa0(2 years 1 month)\nAmity University\nBoard Member - Industry Advisory Board\nSeptember 2025\xa0-\xa0Present\xa0(6 months)\nAcademic–industry collaboration to review and refine program structure\nand syllabus, actively engaging experts to validate curriculum relevance,\nstrengthen research alignment, and ensure strong fit with current industry skills\nand practices.\n\xa0 Page 1 of 2\xa0 \xa0\nAmity University Noida\n13 years 5 months\nAssistant Professor\nAugust 2009\xa0-\xa0December 2022\xa0(13 years 5 months)\nNoida\nAssistant Professor-Department of Artificial intelligence \nAugust 2009\xa0-\xa0November 2022\xa0(13 years 4 months)\nEducation\nThapar Institute of Engineering & Technology\nM E.\xa0\xa0·\xa0(April 2007\xa0-\xa0April 2009)\nAmity University\nDoctor of Philosophy - PhD,\xa0Artificial Intelligence\xa0·\xa0(July 2014\xa0-\xa0December\n2021)\nDIT UNIVERSITY\nBachelor of Technology - BTech,\xa0Electrical and Electronics\nEngineering\xa0·\xa0(2003\xa0-\xa02007)\nThapar Institute of Engineering & Technology\nMaster of Engineering - MEng,\xa0Artificial Intelligence\nThapar Institute of Engineering & Technology\n\xa0 Page 2 of 2\n\nWith this context, please chat with the user, always staying in character as Monika Arora."

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
import gradio as gr

def chat(message, history):
    return "This is a test response!"

gr.ChatInterface(chat).launch(
    inline=False,
    share=False,
    debug=True
)
# Out:
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# Running on local URL:  http://127.0.0.1:7863
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 6
#       3 def chat(message, history):
#       4     return "This is a test response!"
# ----> 6 gr.ChatInterface(chat).launch(
#       7     inline=False,
#       8     share=False,
#       9     debug=True
#      10 )
#
# File ~\Anaconda3\envs\New\lib\site-packages\gradio\blocks.py:2465, in Blocks.launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, auth_dependency, max_file_size, _frontend, enable_monitoring)
#    2457 # If running in a colab or not able to access localhost,
#    2458 # a shareable link must be created.
#    2459 if (
#    2460     _frontend
#    2461     and not wasm_utils.IS_WASM
#    2462     and not networking.url_ok(self.local_url)
#    2463     and not self.share
#    2464 ):
# -> 2465     raise ValueError(
#    2466         "When localhost is not accessible, a shareable link must be created. Please set share=True or check your proxy settings to allow access to localhost."
#    2467     )
#    2469 if self.is_colab and not quiet:
#    2470     if debug:
#
# ValueError: When localhost is not accessible, a shareable link must be created. Please set share=True or check your proxy settings to allow access to localhost.

# %%
def chat(message, history):
    # message: the current string from the user
    # history: a list of lists [[user_1, bot_1], [user_2, bot_2]]
    
    # 1. Build your prompt using the legacy history format
    formatted_history = ""
    for user_msg, bot_msg in history:
        formatted_history += f"User: {user_msg}\nAssistant: {bot_msg}\n"
    
    # 2. Call your model (example)
    # response = my_model.generate(f"{formatted_history}User: {message}")
    response = "This is a test response!" 
    
    return response

# Launch without the 'type' argument
import gradio as gr
gr.ChatInterface(chat).launch(share=True)
# Out:
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# Running on local URL:  http://127.0.0.1:7860
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)

# %%
import gradio as gr

gr.close_all()

def chat(message, history):
    try:
        # Robust way to build history without 'unpacking' errors
        formatted_history = ""
        
        if history:
            for turn in history:
                # Safely check if the turn has at least 2 elements
                if len(turn) >= 2:
                    user_part = turn[0]
                    bot_part = turn[1]
                    formatted_history += f"User: {user_part}\nAssistant: {bot_part}\n"

        # Your actual logic
        response = f"I received: '{message}'. Context length: {len(history)} previous turns."
        
        return response

    except Exception as e:
        # This will catch the error and show it in the chat box instead of crashing
        return f"Debug Error: {str(e)}"

# Re-launch
demo = gr.ChatInterface(chat)
demo.launch()
# Out:
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# Running on local URL:  http://127.0.0.1:7864
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 29
#      27 # Re-launch
#      28 demo = gr.ChatInterface(chat)
# ---> 29 demo.launch()
#
# File ~\Anaconda3\envs\New\lib\site-packages\gradio\blocks.py:2465, in Blocks.launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, auth_dependency, max_file_size, _frontend, enable_monitoring)
#    2457 # If running in a colab or not able to access localhost,
#    2458 # a shareable link must be created.
#    2459 if (
#    2460     _frontend
#    2461     and not wasm_utils.IS_WASM
#    2462     and not networking.url_ok(self.local_url)
#    2463     and not self.share
#    2464 ):
# -> 2465     raise ValueError(
#    2466         "When localhost is not accessible, a shareable link must be created. Please set share=True or check your proxy settings to allow access to localhost."
#    2467     )
#    2469 if self.is_colab and not quiet:
#    2470     if debug:
#
# ValueError: When localhost is not accessible, a shareable link must be created. Please set share=True or check your proxy settings to allow access to localhost.
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 138, in get_asynclib
# KeyError: 'anyio._backends._asyncio'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\gradio\route_utils.py", line 761, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 121, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 107, in app
#     response = await f(request)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\routing.py", line 416, in app
#     solved_result = await solve_dependencies(
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\fastapi\dependencies\utils.py", line 650, in solve_dependencies
#     solved = await run_in_threadpool(call, **solved_result.values)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\starlette\concurrency.py", line 38, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func)
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     abandon_on_cancel: bool = False,
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py", line 140, in get_asynclib
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_backends\_asyncio.py", line 69, in <module>
#     from .._core._eventloop import (
# ImportError: cannot import name 'set_current_async_library' from 'anyio._core._eventloop' (C:\Users\monika201103\Anaconda3\envs\New\lib\site-packages\anyio\_core\_eventloop.py)

# %%
gr.close_all()
# Out:
# Closing server running on port: 7861
# Closing server running on port: 7862
# Closing server running on port: 7860

# %%
import gradio as gr

# 1. Force close any existing apps
gr.close_all()

def chat(message, history):
    # This remains the same as your screenshot
    return "This is a test response!"

# 2. Re-launch
demo = gr.ChatInterface(chat)
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# ...
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\protocols\http\h11_impl.py", line 410, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py", line 1138, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 901, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 917, in simple_response
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 115, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 101, in app
#     response = await f(request)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 355, in app
#     raw_response = await run_endpoint_function(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py", line 243, in run_endpoint_function
#     return await dependant.call(**values)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\routes.py", line 1327, in predict
#     output = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1198, in __enter__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\ProgramData\anaconda3\Lib\threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\ProgramData\anaconda3\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\server.py", line 67, in run
#     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\uvicorn\_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 640, in run_until_complete
#     self.run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\windows_events.py", line 321, in run_forever
#     super().run_forever()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\ProgramData\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     with utils.MatplotlibBackendMananger():
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1207, in __exit__
#     import matplotlib
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# Traceback (most recent call last):
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\blocks.py", line 2152, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\blocks.py", line 1627, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1003, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\chat_interface.py", line 544, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\chat_interface.py", line 905, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\_backends\_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\_backends\_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Local\Temp\1\ipykernel_24652\2149630981.py", line 3, in chat
#     response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\_utils\_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\resources\chat\completions\completions.py", line 1192, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\_base_client.py", line 1294, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\_base_client.py", line 1067, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# Traceback (most recent call last):
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\blocks.py", line 2152, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\blocks.py", line 1627, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\utils.py", line 1003, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\chat_interface.py", line 544, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\chat_interface.py", line 905, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\_backends\_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\_backends\_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Local\Temp\1\ipykernel_24652\2149630981.py", line 3, in chat
#     response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\_utils\_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\resources\chat\completions\completions.py", line 1192, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\_base_client.py", line 1294, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\openai\_base_client.py", line 1067, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 796, in process_events
#     await run_sync(self.compute_analytics_summary, self.event_analytics)
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\_backends\_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\anyio\_backends\_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 183, in compute_analytics_summary
#     df = self._get_df(event_analytics)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\monika201103\AppData\Roaming\Python\Python311\site-packages\gradio\queueing.py", line 160, in _get_df
#     import pandas as pd
#   File "c:\ProgramData\anaconda3\Lib\site-packages\pandas\__init__.py", line 22, in <module>
#     from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\ProgramData\anaconda3\Lib\site-packages\pandas\compat\__init__.py", line 25, in <module>
#     from pandas.compat.numpy import (
#   File "c:\ProgramData\anaconda3\Lib\site-packages\pandas\compat\numpy\__init__.py", line 4, in <module>
#     from pandas.util.version import Version
#   File "c:\ProgramData\anaconda3\Lib\site-packages\pandas\util\__init__.py", line 2, in <module>
#     from pandas.util._decorators import (  # noqa:F401
#   File "c:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py", line 14, in <module>
#     from pandas._libs.properties import cache_readonly
#   File "c:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\__init__.py", line 13, in <module>
#     from pandas._libs.interval import Interval
#   File "pandas\_libs\interval.pyx", line 1, in init pandas._libs.interval
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 gr.ChatInterface(chat, type="messages").launch()
#
# TypeError: ChatInterface.__init__() got an unexpected keyword argument 'type'

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
